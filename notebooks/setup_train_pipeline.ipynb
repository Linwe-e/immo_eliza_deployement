# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (9.2.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (8.1.7)
# Requirement already satisfied: tqdm>=4.62.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.13.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.61.2)
# Requirement already satisfied: requests>=2.27.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (7.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.14.4)
# Requirement already satisfied: sktime==0.26.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from sktime==0.26.0->pycaret) (24.2)
# Requirement already satisfied: scikit-base<0.8.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.3)
# Requirement already satisfied: zipp>=3.20 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.21.0)
# Requirement already satisfied: colorama in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.1)
# Requirement already satisfied: stack_data in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipython>=5.5.0->pycaret) (4.13.2)
# Requirement already satisfied: wcwidth in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.15)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.24.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (310)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from numba>=0.55.0->pycaret) (0.44.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from plotly>=5.14.0->pycaret) (9.1.2)
# Requirement already satisfied: dash>=2.9.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.0.4)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.18)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.6)
# Requirement already satisfied: retrying in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (65.5.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.12)
# Requirement already satisfied: urllib3 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.4.0)
# Requirement already satisfied: six>=1.5 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from requests>=2.27.1->pycaret) (2025.4.26)
# Requirement already satisfied: executing>=1.2.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure-eval in c:\techproject_venv\immoeliza_venv\machinelearning_venv\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Compare models

# %%
# load sample dataset
from pycaret.datasets import get_data
import pandas as pd

data = pd.read_csv('data\Kangaroo_cleaned.csv')

# %%
data.isnull().sum() / len(data) * 100.

data['epcNumeric'].dtype
# Out:
# dtype('float64')

# %%
# Functionnal API
from pycaret.regression import RegressionExperiment
s = RegressionExperiment()
s.setup(data,
        target='price',
        train_size=0.8,
        imputation_type='simple',    
        numeric_imputation='median',
        categorical_imputation='mode',
        normalize=True,                  
        normalize_method='minmax',       # ou 'zscore'
        transformation=True,                          
        remove_multicollinearity=False,
        session_id=42)
# Out:
# <style type="text/css">
# #T_84126_row10_col1, #T_84126_row16_col1, #T_84126_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_84126">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84126_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_84126_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84126_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84126_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_84126_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84126_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_84126_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84126_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_84126_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_84126_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_84126_row3_col1" class="data row3 col1" >(66608, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_84126_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_84126_row4_col1" class="data row4 col1" >(66608, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_84126_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_84126_row5_col1" class="data row5 col1" >(53286, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_84126_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_84126_row6_col1" class="data row6 col1" >(13322, 70)</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_84126_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_84126_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_84126_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_84126_row8_col1" class="data row8 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_84126_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_84126_row9_col1" class="data row9 col1" >94.1%</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_84126_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_84126_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_84126_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_84126_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_84126_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_84126_row12_col1" class="data row12 col1" >median</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_84126_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_84126_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_84126_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_84126_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_84126_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_84126_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_84126_row16_col0" class="data row16 col0" >Transformation</td>
#       <td id="T_84126_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_84126_row17_col0" class="data row17 col0" >Transformation method</td>
#       <td id="T_84126_row17_col1" class="data row17 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_84126_row18_col0" class="data row18 col0" >Normalize</td>
#       <td id="T_84126_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_84126_row19_col0" class="data row19 col0" >Normalize method</td>
#       <td id="T_84126_row19_col1" class="data row19 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_84126_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_84126_row20_col1" class="data row20 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_84126_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_84126_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_84126_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_84126_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_84126_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_84126_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_84126_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_84126_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_84126_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_84126_row25_col1" class="data row25 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_84126_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_84126_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_84126_row26_col1" class="data row26 col1" >7886</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
print(best)
# Out:
# LGBMRegressor(n_jobs=-1, random_state=42)

# %% [markdown]
# # Analyze Model

# %%
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# # Predictions

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2b72e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b72e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2b72e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2b72e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2b72e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2b72e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2b72e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2b72e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b72e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b72e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2b72e_row0_col1" class="data row0 col1" >60337.9149</td>
#       <td id="T_2b72e_row0_col2" class="data row0 col2" >7702934946.0545</td>
#       <td id="T_2b72e_row0_col3" class="data row0 col3" >87766.3657</td>
#       <td id="T_2b72e_row0_col4" class="data row0 col4" >0.7407</td>
#       <td id="T_2b72e_row0_col5" class="data row0 col5" >0.2654</td>
#       <td id="T_2b72e_row0_col6" class="data row0 col6" >0.2147</td>
#     </tr>
#   </tbody>
# </table>
#             type  bedroomCount  bathroomCount         province  \
# 57920      HOUSE           4.0            1.0    West Flanders
# 40124      HOUSE           3.0            NaN          Hainaut
# 56076  APARTMENT           2.0            1.0    West Flanders
# 23578      HOUSE           4.0            1.0          Antwerp
# 51708  APARTMENT           2.0            1.0    West Flanders
# ...          ...           ...            ...              ...
# 9501   APARTMENT           2.0            1.0  Flemish Brabant
# 26967      HOUSE           5.0            2.0  Flemish Brabant
# 55716      HOUSE           4.0            1.0    West Flanders
# 15486      HOUSE           4.0            2.0  Flemish Brabant
# 23517  APARTMENT           2.0            1.0          Antwerp
#
#                  locality  postCode  habitableSurface buildingCondition  \
# 57920              Izegem      8870               NaN            AS_NEW
# 40124               Jumet      6040             134.0     TO_BE_DONE_UP
# 56076        Oostrozebeke      8780              94.0     TO_BE_DONE_UP
# 23578                Niel      2845             275.0              GOOD
# 51708            Ichtegem      8480              72.0              GOOD
# ...                   ...       ...               ...               ...
# 9501            Drogenbos      1620              76.0     TO_BE_DONE_UP
# 26967           Rotselaar      3110             302.0            AS_NEW
# 55716              Wakken      8720             244.0              GOOD
# 15486  RHODE-SAINT-GENÈSE      1640             195.0    JUST_RENOVATED
# 23517              Edegem      2650             100.0              GOOD
#
#        buildingConstructionYear  facedeCount  ... hasSwimmingPool  \
# 57920                    1995.0          3.0  ...           False
# 40124                    1920.0          3.0  ...           False
# 56076                    2005.0          NaN  ...           False
# 23578                       NaN          4.0  ...           False
# 51708                    2019.0          NaN  ...           False
# ...                         ...          ...  ...             ...
# 9501                     1979.0          3.0  ...           False
# 26967                    2025.0          4.0  ...           False
# 55716                       NaN          NaN  ...           False
# 15486                    1950.0          4.0  ...           False
# 23517                    1994.0          2.0  ...           False
#
#       hasFireplace hasTerrace     subtype_grouped  building_floors  \
# 57920        False      False      STANDARD_HOUSE                2
# 40124        False       True      STANDARD_HOUSE                3
# 56076        False      False  STANDARD_APARTMENT                0
# 23578         True      False     LUXURY_PROPERTY                1
# 51708        False      False  STANDARD_APARTMENT                0
# ...            ...        ...                 ...              ...
# 9501         False       True  STANDARD_APARTMENT                0
# 26967        False      False     LUXURY_PROPERTY                0
# 55716        False      False      STANDARD_HOUSE                0
# 15486         True       True     LUXURY_PROPERTY                0
# 23517        False       True  STANDARD_APARTMENT                0
#
#        apartment_floor    region  epcNumeric   price  prediction_label
# 57920                0  Flanders       300.0  570000     355014.409808
# 40124                0  Wallonia       510.0  160000     209140.403773
# 56076                0  Flanders       200.0  165000     211111.006265
# 23578                0  Flanders       200.0  660000     582270.661672
# 51708                0  Flanders       100.0  219000     277545.103604
# ...                ...       ...         ...     ...               ...
# 9501                 3  Flanders       400.0  245000     227361.870588
# 26967                0  Flanders         0.0  878000     841526.361590
# 55716                0  Flanders         NaN  651036     425596.871210
# 15486                0  Flanders       400.0  749000     661485.529144
# 23517                2  Flanders       300.0  289000     298793.780700
#
# [13322 rows x 27 columns]

# %% [markdown]
# # Save model

# %%
s.save_model(best, 'pipeline_immo_eliza')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['bedroomCount', 'bathroomCount',
#                                               'postCode', 'habitableSurface',
#                                               'buildingConstructionYear',
#                                               'facedeCount', 'landSurface',
#                                               'gardenSurface', 'toiletCount',
#                                               'building_floors',
#                                               'apartment_floor', 'epcNumeric'],
#                                      transformer=SimpleImputer(strategy='median'))),
#                  ('categorical...
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['locality'],
#                                      transformer=TargetEncoder(cols=['locality'],
#                                                                handle_missing='return_nan'))),
#                  ('transformation',
#                   TransformerWrapper(transformer=PowerTransformer(standardize=False))),
#                  ('normalize', TransformerWrapper(transformer=MinMaxScaler())),
#                  ('trained_model', LGBMRegressor(n_jobs=-1, random_state=42))]),
#  'pipeline_immo_eliza.pkl')
